# %%
# !pip3 install -q yfinance

# %%
# !pip3 install plotly
# Out:
# ...
#      |████████████████████████████████| 23.9 MB 1.0 MB/s eta 0:00:01
# ...

# %%
# !pip3 install matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 1.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 62.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 67.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
btcData = yf.download("BTC-USD", start = '2014-09-15')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
btcData.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#               Volume
# Date
# 2014-09-17  21056800
# 2014-09-18  34483200
# 2014-09-19  37919700
# 2014-09-20  36863600
# 2014-09-21  26580100

# %%
btcData.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   2567.000000   2567.000000   2567.000000   2567.000000   2567.000000
# mean    9127.115162   9385.004101   8844.528281   9143.106527   9143.106527
# std    13371.376003  13771.349564  12909.272073  13386.569071  13386.569071
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      575.695984    580.758484    571.190491    575.583496    575.583496
# 50%     5312.494629   5422.687500   5224.189941   5324.551758   5324.551758
# 75%     9638.112793   9801.323730   9430.299805   9649.446289   9649.446289
# max    63523.753906  64863.097656  62208.964844  63503.457031  63503.457031
#
#              Volume
# count  2.567000e+03
# mean   1.357840e+10
# std    1.985323e+10
# min    5.914570e+06
# 25%    7.328585e+07
# 50%    4.485800e+09
# 75%    2.162186e+10
# max    3.509679e+11

# %%
#verificando existência de dados nulos:
btcData.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
btcData.to_csv('btcData.csv')

# %%
btcDatacsv = pd.read_csv('btcData.csv')
btcDatacsv
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2562  2021-09-26  42721.628906  43919.300781  40848.460938  43208.539062
# 2563  2021-09-27  43234.183594  44313.246094  42190.632812  42235.730469
# 2564  2021-09-28  42200.898438  42775.144531  40931.664062  41034.542969
# 2565  2021-09-29  41064.984375  42545.257812  40829.667969  41564.363281
# 2566  2021-09-30  41573.269531  44009.011719  41472.578125  43596.253906
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
btcDatacsv.plot(x = 'Date', y = 'Close', figsize = (15,7), title = 'Valor de fechamento diário - Bitcoin');
